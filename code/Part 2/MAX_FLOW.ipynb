# %%
library('igraph')

# %%
tri_graph = read_graph('triangulated_graph.txt',format='ncol',directed=FALSE)
flow1 = max_flow(tri_graph,'1699','660',capacity=as.vector(edge_attr(tri_graph)$weight))
flow1$value
# edge_disjoint_paths(tri_graph,'1699','660')
# Out:
# [1] 14497.24
# [1] 5

# %%
pruned_tri_graph = read_graph('pruned_triangulated_graph.txt',format='ncol',directed=FALSE)
flow2 = max_flow(pruned_tri_graph,'1699','660',capacity=as.vector(edge_attr(tri_graph)$weight))
flow2$value
# edge_disjoint_paths(pruned_tri_graph,'1699','660')
# Out:
# [1] 13755.92
# [1] 5
